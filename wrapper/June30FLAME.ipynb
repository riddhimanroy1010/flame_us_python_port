# %%
pip install pyreadr
# Out:
# Collecting pyreadr
#   Downloading https://files.pythonhosted.org/packages/f1/90/64545feb97a442f67d1f2d582518044024fa9355df924cdad1ff2374fc54/pyreadr-0.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (409kB)
#      |████████████████████████████████| 419kB 3.6MB/s
# Requirement already satisfied: pandas>0.24.0 in /usr/local/lib/python3.7/dist-packages (from pyreadr) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>0.24.0->pyreadr) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>0.24.0->pyreadr) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>0.24.0->pyreadr) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>0.24.0->pyreadr) (1.15.0)
# Installing collected packages: pyreadr
# Successfully installed pyreadr-0.4.2

# %%
pip install rdata
# Out:
# Collecting rdata
#   Downloading https://files.pythonhosted.org/packages/5b/eb/5425f96086dff76f8de3f51f9f7c01cca472cb326ac97d1cef0f7de17270/rdata-0.5-py2.py3-none-any.whl
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from rdata) (0.18.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from rdata) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rdata) (1.19.5)
# Requirement already satisfied: setuptools>=40.4 in /usr/local/lib/python3.7/dist-packages (from xarray->rdata) (57.0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->rdata) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->rdata) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->rdata) (1.15.0)
# Installing collected packages: rdata
# Successfully installed rdata-0.5

# %%
#need to import the libraries I will use 
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import pyreadr
from rpy2.robjects import r
import rpy2.robjects.pandas2ri as pandas2ri
import rdata

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f328de90-5d2c-44e8-aede-f6bcc980e9b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f328de90-5d2c-44e8-aede-f6bcc980e9b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scen_fleet_gwp_f_All Tech Same Vkt.RData to scen_fleet_gwp_f_All Tech Same Vkt.RData

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58ed0ec1-7f20-466c-8c53-b947696ba36b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58ed0ec1-7f20-466c-8c53-b947696ba36b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scen_fleet_vint_stock_f_All Tech Same Vkt.RData to scen_fleet_vint_stock_f_All Tech Same Vkt.RData

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6a7fa3b-3ae1-4b09-a124-f53eb3cb31e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6a7fa3b-3ae1-4b09-a124-f53eb3cb31e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scen_fleet_vkt_f_All Tech Same Vkt.RData to scen_fleet_vkt_f_All Tech Same Vkt.RData

# %%
print(type(uploaded))
print(uploaded)
# Out:
# <class 'dict'>
# {'scen_fleet_vkt_f_All Tech Same Vkt.RData': b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x06\xec\xfd\x07T\x15\xcb\xf6\xaf\r#I\x82\x92\x04\x11$\x08(\x12%\n\x82\x01g\xa9\x88Y\x11\x01ET\x82\t\x05%\x07\xc9H\xceI\x14\x13Q\x10\x11\x94\x0c\x12\x04\x05$\xe7\xa8(9\x88HV\x04\xc3\xbb\xee8\xbd\xd8\xe3\xba\x87\xef\xd9\xe7\xdc\xff}u|_\xf5\x185\xe6^-\xbbW\xf7\xd3\xb3\xaaf\xfd\xba\xd7\x9c\xea;\xb5\xe5\x18\xb4\x19(((\xa8(\xa8I\x8d\x8a\x86\xf4\x9f\x14\xb4;\x0e\xcb\xc8n\x94\xa5\xa0\xa0\xa6$}ZB\xfa\x17z\x92\xa57;kny\xd9\xc2\xfc\xf4e\xd2\x87\x15\xa4F\xfa[\xca\xffe\xa9I\xff\xf7\xff\xb2\xb4\x14\x94\x14L\x14\x14Z\xd2\xdb\xef\xdb\xff\xaf\xc3Pl\xbf\xefL\xd8\xeb\x84\xf5"\xac\x1fa\x83\x08\x1bF\xd8\x9b\x84\xbdC\xd8(\xc2\xc6\x116\x91\xb0\xc9\x84}B\xd8\x0c\xc2\xe6\x106\x9f\xb0\xcf\t\xfb\x92\xb0\xaf\x08[M\xd8z\xc26\x13\xb6\x9d\xb0o\x08\xdbM\xd8~\xc2\x0e\x13\xf6\x03a\'\x08;C\xd89\xc2~\xfd\x97\xfd\xd7\xe9\x93,%a\xa9\x89\x7f\xc7|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3\xc1|0\x1f\xcc\x07\xf3 ...

# %%
parsed = rdata.parser.parse_file(rdata.TESTDATA_PATH / "/content/scen_fleet_vint_stock_f_All Tech Same Vkt.RData")
converted = rdata.conversion.convert(parsed)

# %%
parsed2 = rdata.parser.parse_file(rdata.TESTDATA_PATH / "/content/scen_fleet_vkt_f_All Tech Same Vkt.RData")
converted2 = rdata.conversion.convert(parsed2)

# %%
parsed3 = rdata.parser.parse_file(rdata.TESTDATA_PATH / "/content/scen_fleet_gwp_f_All Tech Same Vkt.RData")
converted3 = rdata.conversion.convert(parsed3)

# %%
print(converted)
# Out:
# {'results_l': [{'fleet_vint_stock':        Age      Value    Year         Size Technology
# 0        0        0.0  1970.0          Car     BEV100
# 1        0        0.0  1970.0          Car     BEV300
# 2        0        0.0  1970.0          Car        CNG
# 3        0        0.0  1970.0          Car        FCV
# 4        0        0.0  1970.0          Car        FFV
# ...    ...        ...     ...          ...        ...
# 50215   30    43203.0  2050.0  Light truck        HEV
# 50216   30     8889.0  2050.0  Light truck     ICEV-D
# 50217   30  1015216.0  2050.0  Light truck     ICEV-G
# 50218   30      790.0  2050.0  Light truck     PHEV20
# 50219   30     5312.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], 'fleet_vint_scrap':        Age      Value    Year         Size Technology
# 0        1        0.0  1971.0          Car     BEV100
# 1        1        0.0  1971.0          Car     BEV300
# 2        1        0.0  1971.0          Car        CNG
# 3        1        0.0  1971.0          Car        FCV
# 4        1        0.0  1971.0          Car        FFV
# ...    ...        ...     ...          ...        ...
# 49595   31    42794.0  2050.0  Light truck        HEV
# 49596   31    13486.0  2050.0  Light truck     ICEV-D
# 49597   31  1160556.0  2050.0  Light truck     ICEV-G
# 49598   31     1548.0  2050.0  Light truck     PHEV20
# 49599   31     4557.0  2050.0  Light truck     PHEV40
#
# [49600 rows x 5 columns], 'Scenario': ['3']}, {'fleet_vint_stock':        Age   Value    Year         Size Technology
# 0        0     0.0  1970.0          Car     BEV100
# 1        0     0.0  1970.0          Car     BEV300
# 2        0     0.0  1970.0          Car        CNG
# 3        0     0.0  1970.0          Car        FCV
# 4        0     0.0  1970.0          Car        FFV
# ...    ...     ...     ...          ...        ...
# 50215   30   570.0  2050.0  Light truck        HEV
# 50216   30    38.0  2050.0  Light truck     ICEV-D
# 50217   30  2341.0  2050.0  Light truck     ICEV-G
# 50218   30   120.0  2050.0  Light truck     PHEV20
# 50219   30   296.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], 'fleet_vint_scrap':        Age   Value    Year         Size Technology
# 0        1     0.0  1971.0          Car     BEV100
# 1        1     0.0  1971.0          Car     BEV300
# 2        1     0.0  1971.0          Car        CNG
# 3        1     0.0  1971.0          Car        FCV
# 4        1     0.0  1971.0          Car        FFV
# ...    ...     ...     ...          ...        ...
# 49595   31   676.0  2050.0  Light truck        HEV
# 49596   31    64.0  2050.0  Light truck     ICEV-D
# 49597   31  2688.0  2050.0  Light truck     ICEV-G
# 49598   31   158.0  2050.0  Light truck     PHEV20
# 49599   31   450.0  2050.0  Light truck     PHEV40
#
# [49600 rows x 5 columns], 'Scenario': ['6']}, {'fleet_vint_stock':        Age     Value    Year         Size Technology
# 0        0       0.0  1970.0          Car     BEV100
# 1        0       0.0  1970.0          Car     BEV300
# 2        0       0.0  1970.0          Car        CNG
# 3        0       0.0  1970.0          Car        FCV
# 4        0       0.0  1970.0          Car        FFV
# ...    ...       ...     ...          ...        ...
# 50215   30   24254.0  2050.0  Light truck        HEV
# 50216   30    1506.0  2050.0  Light truck     ICEV-D
# 50217   30  108299.0  2050.0  Light truck     ICEV-G
# 50218   30    1608.0  2050.0  Light truck     PHEV20
# 50219   30    4025.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], 'fleet_vint_scrap':        Age     Value    Year         Size Technology
# 0        1       0.0  1971.0          Car     BEV100
# 1        1       0.0  1971.0          Car     BEV300
# 2        1       0.0  1971.0          Car        CNG
# 3        1       0.0  1971.0          Car        FCV
# 4        1       0.0  1971.0          Car        FFV
# ...    ...       ...     ...          ...        ...
# 49595   31   27622.0  2050.0  Light truck        HEV
# 49596   31    2489.0  2050.0  Light truck     ICEV-D
# 49597   31  126342.0  2050.0  Light truck     ICEV-G
# 49598   31    2473.0  2050.0  Light truck     PHEV20
# 49599   31    4051.0  2050.0  Light truck     PHEV40
#
# [49600 rows x 5 columns], 'Scenario': ['7']}, {'fleet_vint_stock':        Age     Value    Year         Size Technology
# 0        0       0.0  1970.0          Car     BEV100
# 1        0       0.0  1970.0          Car     BEV300
# 2        0       0.0  1970.0          Car        CNG
# 3        0       0.0  1970.0          Car        FCV
# 4        0       0.0  1970.0          Car        FFV
# ...    ...       ...     ...          ...        ...
# 50215   30   93832.0  2050.0  Light truck        HEV
# 50216   30    9337.0  2050.0  Light truck     ICEV-D
# 50217   30  607024.0  2050.0  Light truck     ICEV-G
# 50218   30    4403.0  2050.0  Light truck     PHEV20
# 50219   30    9368.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], 'fleet_vint_scrap':        Age     Value    Year         Size Technology
# 0        1       0.0  1971.0          Car     BEV100
# 1        1       0.0  1971.0          Car     BEV300
# 2        1       0.0  1971.0          Car        CNG
# 3        1       0.0  1971.0          Car        FCV
# 4        1       0.0  1971.0          Car        FFV
# ...    ...       ...     ...          ...        ...
# 49595   31   96220.0  2050.0  Light truck        HEV
# 49596   31   15339.0  2050.0  Light truck     ICEV-D
# 49597   31  708076.0  2050.0  Light truck     ICEV-G
# 49598   31    8133.0  2050.0  Light truck     PHEV20
# 49599   31    8442.0  2050.0  Light truck     PHEV40
#
# [49600 rows x 5 columns], 'Scenario': ['8']}, {'fleet_vint_stock':        Age      Value    Year         Size Technology
# 0        0        0.0  1970.0          Car     BEV100
# 1        0        0.0  1970.0          Car     BEV300
# 2        0        0.0  1970.0          Car        CNG
# 3        0        0.0  1970.0          Car        FCV
# 4        0        0.0  1970.0          Car        FFV
# ...    ...        ...     ...          ...        ...
# 50215   30   143512.0  2050.0  Light truck        HEV
# 50216   30    18280.0  2050.0  Light truck     ICEV-D
# 50217   30  1200044.0  2050.0  Light truck     ICEV-G
# 50218   30     4143.0  2050.0  Light truck     PHEV20
# 50219   30    12358.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], 'fleet_vint_scrap':        Age      Value    Year         Size Technology
# 0        1        0.0  1971.0          Car     BEV100
# 1        1        0.0  1971.0          Car     BEV300
# 2        1        0.0  1971.0          Car        CNG
# 3        1        0.0  1971.0          Car        FCV
# 4        1        0.0  1971.0          Car        FFV
# ...    ...        ...     ...          ...        ...
# 49595   31   142271.0  2050.0  Light truck        HEV
# 49596   31    28737.0  2050.0  Light truck     ICEV-D
# 49597   31  1405388.0  2050.0  Light truck     ICEV-G
# 49598   31     7772.0  2050.0  Light truck     PHEV20
# 49599   31    10695.0  2050.0  Light truck     PHEV40
#
# [49600 rows x 5 columns], 'Scenario': ['9']}]}

# %%
print(converted2)
# Out:
# {'results_l': [{'fleet_vint_vkt':          Year  Age         Value Technology         Size Unit
# 0      2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1      2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2      2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3      2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4      2019.0    0  1.025435e+11     ICEV-G          Car   km
# ...       ...  ...           ...        ...          ...  ...
# 22315  2046.0   30  0.000000e+00        FCV  Light truck   km
# 22316  2047.0   30  0.000000e+00        FCV  Light truck   km
# 22317  2048.0   30  0.000000e+00        FCV  Light truck   km
# 22318  2049.0   30  0.000000e+00        FCV  Light truck   km
# 22319  2050.0   30  0.000000e+00        FCV  Light truck   km
#
# [22320 rows x 6 columns], 'fleet_vkt':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.995552e+12
# 716          Car     PHEV20  2050.0  2.177172e+10
# 717  Light truck     PHEV20  2050.0  6.458387e+09
# 718          Car     PHEV40  2050.0  2.224581e+09
# 719  Light truck     PHEV40  2050.0  4.353410e+10
#
# [720 rows x 4 columns], 'fleet_vkt_new':        Year  Age         Value Technology         Size Unit
# 0    2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1    2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2    2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3    2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4    2019.0    0  1.025435e+11     ICEV-G          Car   km
# ..      ...  ...           ...        ...          ...  ...
# 715  2046.0    0  4.278980e+06        FCV  Light truck   km
# 716  2047.0    0  4.447083e+06        FCV  Light truck   km
# 717  2048.0    0  4.615185e+06        FCV  Light truck   km
# 718  2049.0    0  4.768006e+06        FCV  Light truck   km
# 719  2050.0    0  4.890263e+06        FCV  Light truck   km
#
# [720 rows x 6 columns], 'Scenario': ['3']}, {'fleet_vint_vkt':          Year  Age         Value Technology         Size Unit
# 0      2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1      2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2      2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3      2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4      2019.0    0  1.025435e+11     ICEV-G          Car   km
# ...       ...  ...           ...        ...          ...  ...
# 22315  2046.0   30  0.000000e+00        FCV  Light truck   km
# 22316  2047.0   30  0.000000e+00        FCV  Light truck   km
# 22317  2048.0   30  0.000000e+00        FCV  Light truck   km
# 22318  2049.0   30  0.000000e+00        FCV  Light truck   km
# 22319  2050.0   30  0.000000e+00        FCV  Light truck   km
#
# [22320 rows x 6 columns], 'fleet_vkt':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.882440e+12
# 716          Car     PHEV20  2050.0  2.355976e+10
# 717  Light truck     PHEV20  2050.0  6.853031e+09
# 718          Car     PHEV40  2050.0  2.441510e+09
# 719  Light truck     PHEV40  2050.0  4.483993e+10
#
# [720 rows x 4 columns], 'fleet_vkt_new':        Year  Age         Value Technology         Size Unit
# 0    2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1    2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2    2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3    2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4    2019.0    0  1.025435e+11     ICEV-G          Car   km
# ..      ...  ...           ...        ...          ...  ...
# 715  2046.0    0  4.278980e+06        FCV  Light truck   km
# 716  2047.0    0  4.447083e+06        FCV  Light truck   km
# 717  2048.0    0  4.615185e+06        FCV  Light truck   km
# 718  2049.0    0  4.768006e+06        FCV  Light truck   km
# 719  2050.0    0  4.890263e+06        FCV  Light truck   km
#
# [720 rows x 6 columns], 'Scenario': ['6']}, {'fleet_vint_vkt':          Year  Age         Value Technology         Size Unit
# 0      2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1      2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2      2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3      2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4      2019.0    0  1.025435e+11     ICEV-G          Car   km
# ...       ...  ...           ...        ...          ...  ...
# 22315  2046.0   30  0.000000e+00        FCV  Light truck   km
# 22316  2047.0   30  0.000000e+00        FCV  Light truck   km
# 22317  2048.0   30  0.000000e+00        FCV  Light truck   km
# 22318  2049.0   30  0.000000e+00        FCV  Light truck   km
# 22319  2050.0   30  1.528207e+04        FCV  Light truck   km
#
# [22320 rows x 6 columns], 'fleet_vkt':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.847715e+12
# 716          Car     PHEV20  2050.0  2.335531e+10
# 717  Light truck     PHEV20  2050.0  7.453127e+09
# 718          Car     PHEV40  2050.0  2.494722e+09
# 719  Light truck     PHEV40  2050.0  4.376667e+10
#
# [720 rows x 4 columns], 'fleet_vkt_new':        Year  Age         Value Technology         Size Unit
# 0    2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1    2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2    2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3    2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4    2019.0    0  1.025435e+11     ICEV-G          Car   km
# ..      ...  ...           ...        ...          ...  ...
# 715  2046.0    0  4.278980e+06        FCV  Light truck   km
# 716  2047.0    0  4.447083e+06        FCV  Light truck   km
# 717  2048.0    0  4.615185e+06        FCV  Light truck   km
# 718  2049.0    0  4.768006e+06        FCV  Light truck   km
# 719  2050.0    0  4.890263e+06        FCV  Light truck   km
#
# [720 rows x 6 columns], 'Scenario': ['7']}, {'fleet_vint_vkt':          Year  Age         Value Technology         Size Unit
# 0      2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1      2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2      2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3      2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4      2019.0    0  1.025435e+11     ICEV-G          Car   km
# ...       ...  ...           ...        ...          ...  ...
# 22315  2046.0   30  0.000000e+00        FCV  Light truck   km
# 22316  2047.0   30  0.000000e+00        FCV  Light truck   km
# 22317  2048.0   30  0.000000e+00        FCV  Light truck   km
# 22318  2049.0   30  0.000000e+00        FCV  Light truck   km
# 22319  2050.0   30  1.528207e+04        FCV  Light truck   km
#
# [22320 rows x 6 columns], 'fleet_vkt':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.832508e+12
# 716          Car     PHEV20  2050.0  2.209849e+10
# 717  Light truck     PHEV20  2050.0  8.182036e+09
# 718          Car     PHEV40  2050.0  2.474779e+09
# 719  Light truck     PHEV40  2050.0  4.360160e+10
#
# [720 rows x 4 columns], 'fleet_vkt_new':        Year  Age         Value Technology         Size Unit
# 0    2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1    2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2    2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3    2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4    2019.0    0  1.025435e+11     ICEV-G          Car   km
# ..      ...  ...           ...        ...          ...  ...
# 715  2046.0    0  4.278980e+06        FCV  Light truck   km
# 716  2047.0    0  4.447083e+06        FCV  Light truck   km
# 717  2048.0    0  4.615185e+06        FCV  Light truck   km
# 718  2049.0    0  4.768006e+06        FCV  Light truck   km
# 719  2050.0    0  4.890263e+06        FCV  Light truck   km
#
# [720 rows x 6 columns], 'Scenario': ['8']}, {'fleet_vint_vkt':          Year  Age         Value Technology         Size Unit
# 0      2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1      2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2      2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3      2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4      2019.0    0  1.025435e+11     ICEV-G          Car   km
# ...       ...  ...           ...        ...          ...  ...
# 22315  2046.0   30  0.000000e+00        FCV  Light truck   km
# 22316  2047.0   30  0.000000e+00        FCV  Light truck   km
# 22317  2048.0   30  0.000000e+00        FCV  Light truck   km
# 22318  2049.0   30  0.000000e+00        FCV  Light truck   km
# 22319  2050.0   30  0.000000e+00        FCV  Light truck   km
#
# [22320 rows x 6 columns], 'fleet_vkt':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.824179e+12
# 716          Car     PHEV20  2050.0  2.040299e+10
# 717  Light truck     PHEV20  2050.0  8.182311e+09
# 718          Car     PHEV40  2050.0  2.407935e+09
# 719  Light truck     PHEV40  2050.0  4.327996e+10
#
# [720 rows x 4 columns], 'fleet_vkt_new':        Year  Age         Value Technology         Size Unit
# 0    2015.0    0  1.004387e+11     ICEV-G          Car   km
# 1    2016.0    0  1.240145e+11     ICEV-G          Car   km
# 2    2017.0    0  1.150863e+11     ICEV-G          Car   km
# 3    2018.0    0  1.104636e+11     ICEV-G          Car   km
# 4    2019.0    0  1.025435e+11     ICEV-G          Car   km
# ..      ...  ...           ...        ...          ...  ...
# 715  2046.0    0  4.278980e+06        FCV  Light truck   km
# 716  2047.0    0  4.447083e+06        FCV  Light truck   km
# 717  2048.0    0  4.615185e+06        FCV  Light truck   km
# 718  2049.0    0  4.768006e+06        FCV  Light truck   km
# 719  2050.0    0  4.890263e+06        FCV  Light truck   km
#
# [720 rows x 6 columns], 'Scenario': ['9']}]}

# %%
print(converted3)
# Out:
# {'results_l': [{'fleet_gwp':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2883  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2884  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2885   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2886 rows x 7 columns], 'Scenario': ['3']}, {'fleet_gwp':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2883  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2884  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2885   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2886 rows x 7 columns], 'Scenario': ['6']}, {'fleet_gwp':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2878  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2879  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2880  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2883 rows x 7 columns], 'Scenario': ['7']}, {'fleet_gwp':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2878  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2879  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2880  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2883 rows x 7 columns], 'Scenario': ['8']}, {'fleet_gwp':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2875  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2876  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2877  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2878  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2879   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2880 rows x 7 columns], 'Scenario': ['9']}]}

# %%
#for stock
print(type(converted))
print("#################")
dt = pd.DataFrame.from_dict(converted)
scenarios_stock = {}
print(converted['results_l'][0].keys())
for num in range(len(converted['results_l'])):
  print(num)
  print("###############")
  for keys in converted['results_l'][num].keys():
    print("**************")
    if keys == 'fleet_vint_stock':
      print(converted['results_l'][num]["Scenario"])
      print(keys, type(converted['results_l'][num][keys]))
      dt = converted['results_l'][num][keys]
      #print(dt)
      scenarios_stock[converted['results_l'][num]["Scenario"][0]] = dt
      #smaller_dt = dt.loc[(dt["Size"] == 'Car') & (dt["Technology"] == "ICEV-G")]["Value"]
      #years = dt.loc[(dt["Size"] == 'Car') & (dt["Technology"] == "ICEV-G")]["Year"]
      #print(years,smaller_dt)
      #plt.plot(years, smaller_dt)
    print("**************")

  print("#############")
print(scenarios_stock)
# Out:
# <class 'dict'>
# #################
# dict_keys(['fleet_vint_stock', 'fleet_vint_scrap', 'Scenario'])
# 0
# ###############
# **************
# ['3']
# fleet_vint_stock <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 1
# ###############
# **************
# ['6']
# fleet_vint_stock <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 2
# ###############
# **************
# ['7']
# fleet_vint_stock <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 3
# ###############
# **************
# ['8']
# fleet_vint_stock <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 4
# ###############
# **************
# ['9']
# fleet_vint_stock <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# {'3':        Age      Value    Year         Size Technology
# 0        0        0.0  1970.0          Car     BEV100
# 1        0        0.0  1970.0          Car     BEV300
# 2        0        0.0  1970.0          Car        CNG
# 3        0        0.0  1970.0          Car        FCV
# 4        0        0.0  1970.0          Car        FFV
# ...    ...        ...     ...          ...        ...
# 50215   30    43203.0  2050.0  Light truck        HEV
# 50216   30     8889.0  2050.0  Light truck     ICEV-D
# 50217   30  1015216.0  2050.0  Light truck     ICEV-G
# 50218   30      790.0  2050.0  Light truck     PHEV20
# 50219   30     5312.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], '6':        Age   Value    Year         Size Technology
# 0        0     0.0  1970.0          Car     BEV100
# 1        0     0.0  1970.0          Car     BEV300
# 2        0     0.0  1970.0          Car        CNG
# 3        0     0.0  1970.0          Car        FCV
# 4        0     0.0  1970.0          Car        FFV
# ...    ...     ...     ...          ...        ...
# 50215   30   570.0  2050.0  Light truck        HEV
# 50216   30    38.0  2050.0  Light truck     ICEV-D
# 50217   30  2341.0  2050.0  Light truck     ICEV-G
# 50218   30   120.0  2050.0  Light truck     PHEV20
# 50219   30   296.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], '7':        Age     Value    Year         Size Technology
# 0        0       0.0  1970.0          Car     BEV100
# 1        0       0.0  1970.0          Car     BEV300
# 2        0       0.0  1970.0          Car        CNG
# 3        0       0.0  1970.0          Car        FCV
# 4        0       0.0  1970.0          Car        FFV
# ...    ...       ...     ...          ...        ...
# 50215   30   24254.0  2050.0  Light truck        HEV
# 50216   30    1506.0  2050.0  Light truck     ICEV-D
# 50217   30  108299.0  2050.0  Light truck     ICEV-G
# 50218   30    1608.0  2050.0  Light truck     PHEV20
# 50219   30    4025.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], '8':        Age     Value    Year         Size Technology
# 0        0       0.0  1970.0          Car     BEV100
# 1        0       0.0  1970.0          Car     BEV300
# 2        0       0.0  1970.0          Car        CNG
# 3        0       0.0  1970.0          Car        FCV
# 4        0       0.0  1970.0          Car        FFV
# ...    ...       ...     ...          ...        ...
# 50215   30   93832.0  2050.0  Light truck        HEV
# 50216   30    9337.0  2050.0  Light truck     ICEV-D
# 50217   30  607024.0  2050.0  Light truck     ICEV-G
# 50218   30    4403.0  2050.0  Light truck     PHEV20
# 50219   30    9368.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns], '9':        Age      Value    Year         Size Technology
# 0        0        0.0  1970.0          Car     BEV100
# 1        0        0.0  1970.0          Car     BEV300
# 2        0        0.0  1970.0          Car        CNG
# 3        0        0.0  1970.0          Car        FCV
# 4        0        0.0  1970.0          Car        FFV
# ...    ...        ...     ...          ...        ...
# 50215   30   143512.0  2050.0  Light truck        HEV
# 50216   30    18280.0  2050.0  Light truck     ICEV-D
# 50217   30  1200044.0  2050.0  Light truck     ICEV-G
# 50218   30     4143.0  2050.0  Light truck     PHEV20
# 50219   30    12358.0  2050.0  Light truck     PHEV40
#
# [50220 rows x 5 columns]}

# %%
#for vkt
print(type(converted2))
print("#################")
dt = pd.DataFrame.from_dict(converted2)
scenarios = {}
print(converted2['results_l'][0].keys())
for num in range(len(converted2['results_l'])):
  print(num)
  print("###############")
  for keys in converted2['results_l'][num].keys():
    print("**************")
    if keys == 'fleet_vkt':
      print(converted2['results_l'][num]["Scenario"])
      print(keys, type(converted2['results_l'][num][keys]))
      dt = converted2['results_l'][num][keys]
      #print(dt)
      scenarios[converted2['results_l'][num]["Scenario"][0]] = dt
      #smaller_dt = dt.loc[(dt["Size"] == 'Car') & (dt["Technology"] == "ICEV-G")]["Value"]
      #years = dt.loc[(dt["Size"] == 'Car') & (dt["Technology"] == "ICEV-G")]["Year"]
      #print(years,smaller_dt)
      #plt.plot(years, smaller_dt)
    print("**************")

  print("#############")
print(scenarios)
# Out:
# <class 'dict'>
# #################
# dict_keys(['fleet_vint_vkt', 'fleet_vkt', 'fleet_vkt_new', 'Scenario'])
# 0
# ###############
# **************
# **************
# **************
# ['3']
# fleet_vkt <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 1
# ###############
# **************
# **************
# **************
# ['6']
# fleet_vkt <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 2
# ###############
# **************
# **************
# **************
# ['7']
# fleet_vkt <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 3
# ###############
# **************
# **************
# **************
# ['8']
# fleet_vkt <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# 4
# ###############
# **************
# **************
# **************
# ['9']
# fleet_vkt <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# **************
# **************
# #############
# {'3':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.995552e+12
# 716          Car     PHEV20  2050.0  2.177172e+10
# 717  Light truck     PHEV20  2050.0  6.458387e+09
# 718          Car     PHEV40  2050.0  2.224581e+09
# 719  Light truck     PHEV40  2050.0  4.353410e+10
#
# [720 rows x 4 columns], '6':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.882440e+12
# 716          Car     PHEV20  2050.0  2.355976e+10
# 717  Light truck     PHEV20  2050.0  6.853031e+09
# 718          Car     PHEV40  2050.0  2.441510e+09
# 719  Light truck     PHEV40  2050.0  4.483993e+10
#
# [720 rows x 4 columns], '7':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.847715e+12
# 716          Car     PHEV20  2050.0  2.335531e+10
# 717  Light truck     PHEV20  2050.0  7.453127e+09
# 718          Car     PHEV40  2050.0  2.494722e+09
# 719  Light truck     PHEV40  2050.0  4.376667e+10
#
# [720 rows x 4 columns], '8':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.832508e+12
# 716          Car     PHEV20  2050.0  2.209849e+10
# 717  Light truck     PHEV20  2050.0  8.182036e+09
# 718          Car     PHEV40  2050.0  2.474779e+09
# 719  Light truck     PHEV40  2050.0  4.360160e+10
#
# [720 rows x 4 columns], '9':             Size Technology    Year         Value
# 0            Car     BEV100  2015.0  2.865373e+09
# 1    Light truck     BEV100  2015.0  1.704409e+08
# 2            Car     BEV300  2015.0  1.021148e+09
# 3    Light truck     BEV300  2015.0  7.393466e+07
# 4            Car        CNG  2015.0  1.849635e+09
# ..           ...        ...     ...           ...
# 715  Light truck     ICEV-G  2050.0  1.824179e+12
# 716          Car     PHEV20  2050.0  2.040299e+10
# 717  Light truck     PHEV20  2050.0  8.182311e+09
# 718          Car     PHEV40  2050.0  2.407935e+09
# 719  Light truck     PHEV40  2050.0  4.327996e+10
#
# [720 rows x 4 columns]}

# %%
#for gwp
print(type(converted3))
print("#################")
dt = pd.DataFrame.from_dict(converted3)
scenarios_gwp = {}
print(converted3['results_l'][0].keys())
for num in range(len(converted3['results_l'])):
  print(num)
  print("###############")
  for keys in converted3['results_l'][num].keys():
    print("**************")
    if keys == 'fleet_gwp':
      print(converted3['results_l'][num]["Scenario"])
      print(keys, type(converted3['results_l'][num][keys]))
      dt = converted3['results_l'][num][keys]
      #print(dt)
      scenarios_gwp[converted3['results_l'][num]["Scenario"][0]] = dt
      #smaller_dt = dt.loc[(dt["Size"] == 'Car') & (dt["Technology"] == "ICEV-G")]["Value"]
      #years = dt.loc[(dt["Size"] == 'Car') & (dt["Technology"] == "ICEV-G")]["Year"]
      #print(years,smaller_dt)
      #plt.plot(years, smaller_dt)
    print("**************")

  print("#############")
print(scenarios_gwp)
# Out:
# <class 'dict'>
# #################
# dict_keys(['fleet_gwp', 'Scenario'])
# 0
# ###############
# **************
# ['3']
# fleet_gwp <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# #############
# 1
# ###############
# **************
# ['6']
# fleet_gwp <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# #############
# 2
# ###############
# **************
# ['7']
# fleet_gwp <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# #############
# 3
# ###############
# **************
# ['8']
# fleet_gwp <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# #############
# 4
# ###############
# **************
# ['9']
# fleet_gwp <class 'pandas.core.frame.DataFrame'>
# **************
# **************
# **************
# #############
# {'3':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2883  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2884  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2885   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2886 rows x 7 columns], '6':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2883  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2884  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2885   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2886 rows x 7 columns], '7':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2878  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2879  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2880  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2883 rows x 7 columns], '8':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2878  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2879  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2880  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2881  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2882   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2883 rows x 7 columns], '9':               Sector                        Phase  ...  GHG        Unit
# 0      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 1      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 2      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 3      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# 4      Manufacturing  Primary Material Production  ...  CO2  kg CO2 eq.
# ...              ...                          ...  ...  ...         ...
# 2875  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2876  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2877  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2878  Transportation                     Fuel Use  ...  N2O  kg CO2 eq.
# 2879   Manufacturing                  End of Life  ...  N2O  kg CO2 eq.
#
# [2880 rows x 7 columns]}

# %%
#need to groupby year for each vkt
base_case_vkt = scenarios["3"].copy()
twenty_year_vkt= scenarios["6"].copy()
fifteen_year_vkt= scenarios["7"].copy()
ten_year_vkt= scenarios["8"].copy()
five_year_vkt= scenarios["9"].copy()

basecase_vkt_byyear = base_case_vkt.groupby(['Year'])['Value'].sum().reset_index()
twenty_year_vkt_byyear = twenty_year_vkt.groupby(['Year'])['Value'].sum().reset_index()
fifteen_year_vkt_byyear = fifteen_year_vkt.groupby(['Year'])['Value'].sum().reset_index()
ten_year_vkt_byyear = ten_year_vkt.groupby(['Year'])['Value'].sum().reset_index()
five_year_vkt_byyear = five_year_vkt.groupby(['Year'])['Value'].sum().reset_index()

basecase_vkt_byyear['20 Year Cut_Off'] = twenty_year_vkt_byyear['Value']
basecase_vkt_byyear['15 Year Cut_Off'] = fifteen_year_vkt_byyear['Value']
basecase_vkt_byyear['10 Year Cut_Off'] = ten_year_vkt_byyear['Value']
basecase_vkt_byyear['5 Year Cut_Off'] = five_year_vkt_byyear['Value']

basecase_vkt_byyear_toplot = basecase_vkt_byyear.set_index('Year')

plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
fig = plt.figure(figsize=(20,10))
plt.plot(basecase_vkt_byyear_toplot.index , basecase_vkt_byyear_toplot, '-o')
plt.xlabel('Year', fontsize=18)
plt.ylabel('Total VKT (km)', fontsize=16)
plt.legend(basecase_vkt_byyear_toplot.columns, loc='best', ncol=3)

# %%
#need to groupby year for each gwp
#kg co2e
base_case_gwp = scenarios_gwp["3"].copy()
twenty_year_gwp= scenarios_gwp["6"].copy()
fifteen_year_gwp= scenarios_gwp["7"].copy()
ten_year_gwp= scenarios_gwp["8"].copy()
five_year_gwp= scenarios_gwp["9"].copy()

basecase_gwp_byyear = base_case_gwp.groupby(['Year'])['Value'].sum().reset_index()
twenty_year_gwp_byyear = twenty_year_gwp.groupby(['Year'])['Value'].sum().reset_index()
fifteen_year_gwp_byyear = fifteen_year_gwp.groupby(['Year'])['Value'].sum().reset_index()
ten_year_gwp_byyear = ten_year_gwp.groupby(['Year'])['Value'].sum().reset_index()
five_year_gwp_byyear = five_year_gwp.groupby(['Year'])['Value'].sum().reset_index()

basecase_gwp_byyear['20 Year Cut_Off'] = twenty_year_gwp_byyear['Value']
basecase_gwp_byyear['15 Year Cut_Off'] = fifteen_year_gwp_byyear['Value']
basecase_gwp_byyear['10 Year Cut_Off'] = ten_year_gwp_byyear['Value']
basecase_gwp_byyear['5 Year Cut_Off'] = five_year_gwp_byyear['Value']

basecase_gwp_byyear_toplot = basecase_gwp_byyear.set_index('Year')

plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
fig = plt.figure(figsize=(20,10))
plt.plot(basecase_gwp_byyear_toplot.index , basecase_gwp_byyear_toplot, '-o')
plt.xlabel('Year', fontsize=18)
plt.ylabel('Total GHG Emissions (kg C02e)', fontsize=16)
plt.legend(basecase_gwp_byyear_toplot.columns, loc='best', ncol=3)

# %%
#a little more complicated for stock
#units are number of cars
#first will do total number of cars
base_case_stock = scenarios_stock["3"].copy()
twenty_year_stock= scenarios_stock["6"].copy()
fifteen_year_stock= scenarios_stock["7"].copy()
ten_year_stock= scenarios_stock["8"].copy()
five_year_stock= scenarios_stock["9"].copy()

basecase_stock_byyear = base_case_stock.groupby(['Year'])['Value'].sum().reset_index()
twenty_year_stock_byyear = twenty_year_stock.groupby(['Year'])['Value'].sum().reset_index()
fifteen_year_stock_byyear = fifteen_year_stock.groupby(['Year'])['Value'].sum().reset_index()
ten_year_stock_byyear = ten_year_stock.groupby(['Year'])['Value'].sum().reset_index()
five_year_stock_byyear = five_year_stock.groupby(['Year'])['Value'].sum().reset_index()

basecase_stock_byyear['20 Year Cut_Off'] = twenty_year_stock_byyear['Value']
basecase_stock_byyear['15 Year Cut_Off'] = fifteen_year_stock_byyear['Value']
basecase_stock_byyear['10 Year Cut_Off'] = ten_year_stock_byyear['Value']
basecase_stock_byyear['5 Year Cut_Off'] = five_year_stock_byyear['Value']

basecase_stock_byyear_toplot = basecase_stock_byyear.set_index('Year')

plt.rcParams['xtick.labelsize'] = 18
plt.rcParams['ytick.labelsize'] = 18
fig = plt.figure(figsize=(20,10))
plt.plot(basecase_stock_byyear_toplot.index , basecase_stock_byyear_toplot, '-o')
plt.xlabel('Year', fontsize=18)
plt.ylabel('Total Number of Cars', fontsize=16)
plt.legend(basecase_stock_byyear_toplot.columns, loc='best', ncol=3)

# %%
#total number of EVS
base_case_stock2 = scenarios_stock["3"].copy()
twenty_year_stock2= scenarios_stock["6"].copy()
fifteen_year_stock2= scenarios_stock["7"].copy()
ten_year_stock2= scenarios_stock["8"].copy()
five_year_stock2= scenarios_stock["9"].copy()

basecase_stock_byyear2 = base_case_stock2.groupby(['Year','Technology'])['Value'].sum().reset_index()
basecase_stock_byyear2=basecase_stock_byyear2.pivot_table(values='Value', index='Year', columns='Technology', aggfunc=sum)

twenty_year_stock_byyear2 = twenty_year_stock2.groupby(['Year','Technology'])['Value'].sum().reset_index()
twenty_year_stock_byyear2=twenty_year_stock_byyear2.pivot_table(values='Value', index='Year', columns='Technology', aggfunc=sum)

fifteen_year_stock2 = fifteen_year_stock2.groupby(['Year','Technology'])['Value'].sum().reset_index()
fifteen_year_stock2=fifteen_year_stock2.pivot_table(values='Value', index='Year', columns='Technology', aggfunc=sum)

ten_year_stock_byyear2 = ten_year_stock2.groupby(['Year','Technology'])['Value'].sum().reset_index()
ten_year_stock_byyear2=ten_year_stock_byyear2.pivot_table(values='Value', index='Year', columns='Technology', aggfunc=sum)

five_year_stock_byyear2 = five_year_stock2.groupby(['Year','Technology'])['Value'].sum().reset_index()
five_year_stock_byyear2 =five_year_stock_byyear2.pivot_table(values='Value', index='Year', columns='Technology', aggfunc=sum)

basecase_stock_byyear2

plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
fig = plt.figure(figsize=(20,20))

# using subplot function and creating plot one
plt.subplot(3, 2, 1)  # row 3, column 2, count 1
plt.plot(basecase_stock_byyear2.index, basecase_stock_byyear2, '-')
plt.title('Base Case')
plt.xlabel('Year')
plt.ylabel('Number of Cars')
plt.legend(basecase_stock_byyear2.columns, loc='best', ncol=3)

plt.subplot(3, 2, 2)  # row 3, column 2, count 1
plt.plot(twenty_year_stock_byyear2.index,twenty_year_stock_byyear2, '-')
plt.title('20 Year Cutoff')
plt.xlabel('Year')
plt.ylabel('Number of Cars')
plt.legend(five_year_stock_byyear2.columns, loc='best', ncol=3)

plt.subplot(3, 2, 3)  # row 3, column 2, count 1
plt.plot(fifteen_year_stock2.index, fifteen_year_stock2, '-')
plt.title('15 Year Cutoff')
plt.xlabel('Year')
plt.ylabel('Number of Cars')
plt.legend(five_year_stock_byyear2.columns, loc='best', ncol=3)

plt.subplot(3, 2, 4)  # row 3, column 2, count 1
plt.plot(ten_year_stock_byyear2.index, ten_year_stock_byyear2, '-')
plt.title('10 Year Cutoff')
plt.xlabel('Year')
plt.ylabel('Number of Cars')
plt.legend(five_year_stock_byyear2.columns, loc='best', ncol=3)

plt.subplot(3, 2, 5)  # row 3, column 2, count 1
plt.plot(five_year_stock_byyear2.index, five_year_stock_byyear2, '-')
plt.title('Five Year Cutoff')
plt.xlabel('Year')
plt.ylabel('Number of Cars')
plt.legend(five_year_stock_byyear2.columns, loc='best', ncol=3)

# %%
#total number of gasoline vehicles
